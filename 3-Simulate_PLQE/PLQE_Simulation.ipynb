# %%
from Manuel_BayesPLQE_Functions import *
import numpy as np

# %%
Thickness = 600 #nm
laser = '450 nm'    #choose: '405 nm', '450 nm', '532 nm' or '660 nm'
save = 'no'

normalize = [True, True, True]    #or False
k_aug_guess = 1e-28

data_folder_nc = r"Example_Data/TRPL"
sample_names = ["Seo_FAPI_nuts_drawn_samples.dat","Seo_Spiro_drawn_samples.dat","Seo_SnO2_drawn_samples.dat"]

PLQE_file_name = r"Example_Data/PLQE\PLQEs_combined.csv"
PLQE_sample_names = ["Seo_FAPI_1","Seo_FAPI_Spiro_1", "Seo_FAPI_TiO2_SnO2_1"]
PLQE_power_names = ["Power_Seo_FAPI_1(W)","Power_Seo_FAPI_Spiro_1(W)","Power_Seo_FAPI_TiO2_SnO2_1(W)"]

# %%
for i in np.arange(1)+0:#len(PLQE_sample_names)):
    simulate_PLQE(Thickness, laser, normalize[i], k_aug_guess, data_folder_nc, sample_names[i], PLQE_file_name,  PLQE_sample_names[i], save, 200)
# Out:
# [0.32879578 0.36113253 0.4002128  0.44986459 0.50539134 0.56490808
#  0.61538193 0.65604346 0.68052955 0.69160882 0.69197715 0.68762646
#  0.67582404 0.6614184 ]
# $P_{\mathrm{esc.}}$: 2.41%
